# %%
import numpy as np
import pandas as pd
import os

#opens the .csv file for reading using "r"
fear_text = open("../input/ferdataset/icml_face_data.csv", "r")

fear_text = ''.join([i for i in text])

#.replace is a function used to return a copy of a string when all occurences of a substring are replaced with another substring
.replace("1,", "0,").replace("3,", "0,").replace("4,", "0,").replace("5,", "0,").replace("6,", "0,")

#opens the .csv file with a new name in write mode using "w"
fear = open("fear_face_data.csv", "w")

#.writelines inserts the changes made by the ".replace" into the newly named .csv
fear.writelines(text)
#".close" closes the opened file
fear.close()

#anger
anger_text = open("../input/ferdataset/icml_face_data.csv", "r")
anger_text = ''.join([i for i in text])
.replace("2,", "1,").replace("3,", "1,").replace("4,", "1,").replace("5,", "1,").replace("6,", "1,")
anger = open("angry_face_data.csv", "w")
anger.writelines(anger_text)
anger.close()

#disgust
disgust_text = open("../input/ferdataset/icml_face_data.csv", "r")
disgust_text = ''.join([i for i in text])
.replace("2,", "0,").replace("3,", "0,").replace("4,", "0,").replace("5,", "0,").replace("6,", "0,")
disgust = open("disgust_face_data.csv", "w")
disgust.writelines(disgust_text)
disgust.close()

#happy
happy_text = open("../input/ferdataset/icml_face_data.csv", "r")
happy_text = ''.join([i for i in text])
.replace("2,", "0,").replace("1,", "0,").replace("4,", "0,").replace("5,", "0,").replace("6,", "0,")
happy = open("happy_face_data.csv", "w")
happy.writelines(happy_text)
happy.close()

#neutral
neutral_text = open("../input/ferdataset/icml_face_data.csv", "r")
neutral_text = ''.join([i for i in text])
.replace("2,", "0,").replace("1,", "0,").replace("4,", "0,").replace("5,", "0,").replace("3,", "0,")
neutral = open("neutral_face_data.csv", "w")
neutral.writelines(neutral_text)
neutral.close()

#sad
sad_text = open("../input/ferdataset/icml_face_data.csv", "r")
sad_text = ''.join([i for i in text])
.replace("2,", "0,").replace("1,", "0,").replace("6,", "0,").replace("5,", "0,").replace("3,", "0,")
sad = open("sad_face_data.csv", "w")
sad.writelines(sad_text)
sad.close()

#surprise
surprise_text = open("../input/ferdataset/icml_face_data.csv", "r")
surprise_text = ''.join([i for i in text])
.replace("2,", "0,").replace("1,", "0,").replace("6,", "0,").replace("4,", "0,").replace("3,", "0,")
surprise = open("surprise_face_data.csv", "w")
surprise.writelines(surprise_text)
surprise.close()
